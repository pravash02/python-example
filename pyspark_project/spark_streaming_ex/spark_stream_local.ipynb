# %%
import findspark
findspark.init('/Users/pravashpanigrahi/spark-3.0.2-bin-hadoop2.7')

import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

from pyspark import SparkContext
from pyspark.streaming import StreamingContext

sc = SparkContext('local[*]', 'NetworkWordCount')

streamsc = StreamingContext(sc, 5)  # '5' indicates the the time interval

lines = streamsc.socketTextStream('localhost', 2222)

words = lines.flatMap(lambda line: line.split(' '))

pairs = words.map(lambda word: (word, 1))

word_counts = pairs.reduceByKey(lambda x, y: x + y)

word_counts.pprint()

streamsc.start()
# Out:
# -------------------------------------------
# Time: 2021-03-30 00:42:05
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-30 00:42:10
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-30 00:42:15
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-30 00:42:20
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-30 00:42:25
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-30 00:42:30
# -------------------------------------------
# ('', 1)
# ('hello', 1)
#
# -------------------------------------------
# Time: 2021-03-30 00:42:35
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-30 00:42:40
# -------------------------------------------
# ('hello', 1)
# ('another', 1)
# ('from', 1)
# ('terminal', 1)
#
# -------------------------------------------
# Time: 2021-03-30 00:42:45
# -------------------------------------------
# ('hihihihi', 1)
#
# -------------------------------------------
# Time: 2021-03-30 00:42:50
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-30 00:42:55
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-30 00:43:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-30 00:43:05
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-30 00:43:10
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-30 00:43:15
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-30 00:43:20
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-30 00:43:25
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-30 00:43:30
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-30 00:43:35
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-30 00:43:40
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-30 00:43:45
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-30 00:43:50
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-30 00:43:55
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-30 00:44:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-30 00:44:05
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-30 00:44:10
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-30 00:44:15
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-30 00:44:20
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-30 00:44:25
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-30 00:44:30
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-30 00:44:35
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-30 00:44:40
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-30 00:44:45
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-30 00:44:50
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-30 00:44:55
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-30 00:45:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-30 00:45:05
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-30 00:45:10
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-30 00:45:15
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-03-30 00:45:20
# -------------------------------------------
